# %% [markdown]
# # GlassCut – Live Dataset Performance Profiling
#
# This notebook measures **where time is actually spent** when converting a slide to tiles with `LiveSlideDataset`.
#
# Two complementary profilers are used:
# * **`pyinstrument`** – call-stack sampling (wall-clock, zero configuration)
# * **`line_profiler`** – line-by-line timing of the hottest functions
#
# Install once:
# ```bash
# uv add --group dev pyinstrument line_profiler
# ```

# %%
# ── stdlib ──────────────────────────────────────────────────────────────
import time
import copy

# ── glasscut ────────────────────────────────────────────────────────────
from glasscut import Slide
from glasscut.data import breast_tissue
from glasscut.dataset import LiveSlideDataset
from glasscut.tiler import GridTiler
from glasscut.tissue_detectors import OtsuTissueDetector
from glasscut.slides.utils import magnification_to_level

# Grab the cached slide used in the usage guide
_, slide_path = breast_tissue()
print(f"Slide: {slide_path}")
# Out:
# Slide: /home/camilo/.cache/glasscut-data/tcga/breast/TCGA-A8-A082-01A-01-TS1.3cad4a77-47a6-4658-becf-d8cffa161d3a.svs

# %% [markdown]
# ## 1. Baseline wall-clock time

# %%
tiler = GridTiler(
    tile_size=(512, 512),
    magnification=20,
    min_tissue_ratio=0.2,
    show_progress=True,
)

dataset = LiveSlideDataset(
    slide_paths=[str(slide_path)],
    tiler=tiler,
    n_workers=4,
    batch_size=128,
    use_cucim=True,
)

t0 = time.perf_counter()
sample = dataset[0]
elapsed = time.perf_counter() - t0

print(f"\n✓ {len(sample.tiles)} tiles extracted in {elapsed:.2f}s")
# Out:
# Extracting tile batches: 100%|██████████| 7/7 [00:06<00:00,  1.08batch/s]
# ✓ 883 tiles extracted in 6.74s

# %% [markdown]
# ## 2. pyinstrument – call-stack profiler (no code changes needed)
#
# Gives a flamegraph-style view of where wall time goes.

# %%
from pyinstrument import Profiler

tiler2 = GridTiler(
    tile_size=(512, 512), magnification=20, min_tissue_ratio=0.2, show_progress=False
)
dataset2 = LiveSlideDataset(
    slide_paths=[str(slide_path)],
    tiler=tiler2,
    n_workers=4,
    batch_size=128,
    use_cucim=True,
)

profiler = Profiler()
with profiler:
    _ = dataset2[0]

profiler.print(color=True)
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 09:24:57  Samples:  895
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 6.731     CPU time: 26.213
# /   _/                      v5.1.2
#
# Profile at /tmp/ipykernel_1354288/2963110443.py:15
#
# 6.730 <module>  /tmp/ipykernel_1354288/2963110443.py:1
# └─ 6.730 LiveSlideDataset.__getitem__  ../../glasscut/dataset/live.py:82
#    └─ 6.710 GridTiler.extract  ../../glasscut/tiler/grid.py:160
#       ├─ 6.506 result_iterator  concurrent/futures/_base.py:612
#       │     [3 frames hidden]  concurrent, threading
#       │        6.461 lock.acquire  <built-in>
#       └─ 0.162 GridTiler.get_tile_candidates  ../../glasscut/tiler/grid.py:78
#          └─ 0.158 GridTiler._slide_tissue_mask  ../../glasscut/tiler/grid.py:254
#             └─ 0.156 Slide.thumbnail  ../../glasscut/slides/slide.py:156
#                └─ 0.156 OpenSlideBackend.get_thumbnail  ../../glasscut/slides/backends/openslide_backend.py:118
#                   └─ 0.156 OpenSlide.get_thumbnail  openslide/__init__.py:172
#                         [2 frames hidden]  openslide

# %% [markdown]
# ## 3. Manual phase breakdown
#
# Break the pipeline into **3 phases** and time each independently:
#
# | Phase | What happens |
# |---|---|
# | A – Thumbnail + tissue mask | `slide.thumbnail` + `OtsuTissueDetector.detect()` |
# | B – Candidate selection | Loop over grid, sample mask, filter by ratio |
# | C – Extraction + transforms | `GridTiler._extract_and_transform` via `ThreadPoolExecutor` (fused I/O + transforms) |

# %%
import math
import numpy as np
from concurrent.futures import ThreadPoolExecutor
from glasscut.tile import Tile

TILE_SIZE = (512, 512)
MAGNIFICATION = 20
MIN_TISSUE_RATIO = 0.2
N_WORKERS = 4
BATCH_SIZE = 128

detector = OtsuTissueDetector()
times: dict[str, float] = {}

tiler_ph = GridTiler(
    tile_size=TILE_SIZE,
    magnification=MAGNIFICATION,
    min_tissue_ratio=MIN_TISSUE_RATIO,
    show_progress=False,
)

with Slide(str(slide_path), use_cucim=True) as slide:

    # ── Phase A: thumbnail + tissue mask ──────────────────────────────────
    t = time.perf_counter()
    thumbnail = slide.thumbnail                          # lazyproperty – first access
    tissue_mask = np.asarray(detector.detect(thumbnail)) > 0
    times["A_thumbnail+mask"] = time.perf_counter() - t

    # ── Phase B: candidate selection ──────────────────────────────────────
    t = time.perf_counter()
    candidates = tiler_ph.get_tile_candidates(slide)
    times["B_candidate_selection"] = time.perf_counter() - t
    print(f"Candidates: {len(candidates)}")

    # ── Phase C: fused extraction + transforms (GridTiler owns the pool) ──
    # extract_tiles no longer lives on Slide; GridTiler._extract_and_transform
    # handles read_region + tissue ratio + transform pipeline in each thread.
    t = time.perf_counter()
    all_tiles: list[Tile] = []
    for start in range(0, len(candidates), BATCH_SIZE):
        batch = candidates[start : start + BATCH_SIZE]
        with ThreadPoolExecutor(max_workers=N_WORKERS) as executor:
            batch_tiles = list(
                executor.map(
                    lambda item: tiler_ph._extract_and_transform(slide, item),
                    batch,
                )
            )
        all_tiles.extend(batch_tiles)
    times["C_extraction+transforms"] = time.perf_counter() - t

total = sum(times.values())
print("\n── Phase breakdown ─────────────────────────────────────────")
for phase, t in times.items():
    print(f"  {phase:<30s}  {t:6.3f}s  ({100*t/total:.1f}%)")
print(f"  {'TOTAL':<30s}  {total:6.3f}s")
# Out:
# Candidates: 883
#
# ── Phase breakdown ─────────────────────────────────────────
#   A_thumbnail+mask                 0.177s  (2.6%)
#   B_candidate_selection            0.005s  (0.1%)
#   C_extraction+transforms          6.682s  (97.3%)
#   TOTAL                            6.865s

# %% [markdown]
# ## 4. line_profiler – per-line timing of the hottest functions

# %%
# %load_ext line_profiler

from glasscut.tiler.grid import GridTiler

tiler3 = GridTiler(
    tile_size=(512, 512), magnification=20, min_tissue_ratio=0.2, show_progress=False
)

with Slide(str(slide_path), use_cucim=True) as slide3:
    # Profile candidate selection (Phase B)
    # %lprun -f tiler3.get_tile_candidates tiler3.get_tile_candidates(slide3)
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler
# Timer unit: 1e-09 s
#
# Total time: 0.191103 s
# File: /home/camilo/GlassCut/glasscut/tiler/grid.py
# Function: GridTiler.get_tile_candidates at line 78
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     78                                               def get_tile_candidates(
#     79                                                   self,
#     80                                                   slide: Slide,
#     81                                               ) -> list[_Candidate]:
#     82                                                   """Return preselected boxes with tissue ratio as ``(x, y, w, h, ratio)``."""
#     83         1       5263.0   5263.0      0.0          self._validate_overlap(self.overlap, self.tile_size)
#     84
#     85         1     513280.0 513280.0      0.3          level = magnification_to_level(self.magnification, slide.magnifications)
#     86         1        301.0    301.0      0.0          downsample: int = 2**level
#     87
#     88         1        670.0    670.0      0.0          tile_w, tile_h = self.tile_size
#     89         1        541.0    541.0      0.0          step_x = tile_w - self.overlap
#     90         1        196.0    196.0      0.0          step_y = tile_h - self.overlap
#     91         1        337.0    337.0      0.0          if step_x <= 0 or step_y <= 0:
#     92                                                       raise ValueError(
#     93                                                           "Grid step must be positive. Reduce overlap or increase tile_size."
#     94                                                       )
#     95
#     96         1      36007.0  36007.0      0.0          slide_w_lvl0: int = slide.dimensions[0]
#     97         1        441.0    441.0      0.0          slide_h_lvl0: int = slide.dimensions[1]
#     98         1        465.0    465.0      0.0          slide_w_lvl = slide_w_lvl0 // downsample
#     99         1        267.0    267.0      0.0          slide_h_lvl = slide_h_lvl0 // downsample
#    100
#    101         2      16298.0   8149.0      0.0          with self._profiler.phase("tissue_mask"):
#    102         1  186519719.0 1.87e+08     97.6              tissue_mask = self._slide_tissue_mask(slide)  # bool H×W
#    103         1       2292.0   2292.0      0.0          mask_h: int = tissue_mask.shape[0]
#    104         1        450.0    450.0      0.0          mask_w: int = tissue_mask.shape[1]
#    105
#    106         1        433.0    433.0      0.0          boxes_lvl0: list[_Candidate] = []
#    107
#    108         2      13424.0   6712.0      0.0          with self._profiler.phase("candidate_grid"):
#    109                                                       # ── Integral image for O(1) region-mean queries ────────────────
#    110                                                       # sat[i, j] = sum of tissue_mask[0:i, 0:j] (1-indexed padded form)
#    111         1      99208.0  99208.0      0.1              mask_f = tissue_mask.astype(np.float32)
#    112         1     155770.0 155770.0      0.1              sat = np.zeros((mask_h + 1, mask_w + 1), dtype=np.float64)
#    113         1    2128443.0 2.13e+06      1.1              sat[1:, 1:] = np.cumsum(np.cumsum(mask_f, axis=0), axis=1)
#    114
#    115         1       2832.0   2832.0      0.0              max_y = max(slide_h_lvl - tile_h, 0)
#    116         1       1189.0   1189.0      0.0              max_x = max(slide_w_lvl - tile_w, 0)
#    117
#    118                                                       # Precompute scale factors
#    119         1       1154.0   1154.0      0.0              sx = mask_w / slide_w_lvl0
#    120         1        887.0    887.0      0.0              sy = mask_h / slide_h_lvl0
#    121         1        815.0    815.0      0.0              w0 = tile_w * downsample
#    122         1        696.0    696.0      0.0              h0 = tile_h * downsample
#    123
#    124         1       8141.0   8141.0      0.0              cols = np.arange(0, max_x + 1, step_x)
#    125         1       1764.0   1764.0      0.0              rows = np.arange(0, max_y + 1, step_y)
#    126         1       2873.0   2873.0      0.0              if cols.size == 0 or rows.size == 0:
#    127                                                           return []
#    128
#    129         1     168217.0 168217.0      0.1              col_grid, row_grid = np.meshgrid(cols, rows)
#    130
#    131         1       9034.0   9034.0      0.0              x0_all = col_grid * downsample
#    132         1       4828.0   4828.0      0.0              y0_all = row_grid * downsample
#    133
#    134         1      86497.0  86497.0      0.0              mx0 = np.clip((x0_all * sx).astype(np.int64), 0, mask_w - 1)
#    135         1      27037.0  27037.0      0.0              my0 = np.clip((y0_all * sy).astype(np.int64), 0, mask_h - 1)
#    136         2      17778.0   8889.0      0.0              mx1 = np.clip(
#    137         1      19793.0  19793.0      0.0                  np.ceil((x0_all + w0) * sx).astype(np.int64), mx0 + 1, mask_w
#    138                                                       )
#    139         2      16168.0   8084.0      0.0              my1 = np.clip(
#    140         1      13158.0  13158.0      0.0                  np.ceil((y0_all + h0) * sy).astype(np.int64), my0 + 1, mask_h
#    141                                                       )
#    142
#    143         1       9616.0   9616.0      0.0              area = (mx1 - mx0) * (my1 - my0)
#    144         1        292.0    292.0      0.0              total = (
#    145         4      39507.0   9876.8      0.0                  sat[my1, mx1]
#    146         1      20404.0  20404.0      0.0                  - sat[my0, mx1]
#    147         1      12306.0  12306.0      0.0                  - sat[my1, mx0]
#    148         1      12793.0  12793.0      0.0                  + sat[my0, mx0]
#    149                                                       )
#    150         1       7128.0   7128.0      0.0              tissue_ratios = total / area
#    151
#    152         1       5325.0   5325.0      0.0              keep = tissue_ratios >= self.min_tissue_ratio
#    153       884     313254.0    354.4      0.2              boxes_lvl0 = [
#    154       883     539994.0    611.5      0.3                  (int(x), int(y), int(w0), int(h0), float(r))
#    155       884     262007.0    296.4      0.1                  for x, y, r in zip(x0_all[keep], y0_all[keep], tissue_ratios[keep])
#    156                                                       ]
#    157
#    158         1       3438.0   3438.0      0.0          return boxes_lvl0

# %%
from glasscut.tiler.grid import GridTiler

tiler4 = GridTiler(
    tile_size=(512, 512), magnification=20, min_tissue_ratio=0.2, show_progress=False
)

with Slide(str(slide_path), use_cucim=True) as slide4:
    candidates4 = tiler4.get_tile_candidates(slide4)

    # Profile the fused per-tile worker (Phase C inner loop):
    # _extract_and_transform does: extract_tile → set_tissue_ratio → transforms
    # %lprun -f tiler4._extract_and_transform -f slide4.extract_tile list(map(lambda c: tiler4._extract_and_transform(slide4, c), candidates4[:BATCH_SIZE]))
# Out:
# Timer unit: 1e-09 s
#
# Total time: 3.5647 s
# File: /home/camilo/GlassCut/glasscut/tiler/grid.py
# Function: GridTiler._extract_and_transform at line 201
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    201                                               def _extract_and_transform(
#    202                                                   self,
#    203                                                   slide: Slide,
#    204                                                   candidate: _Candidate,
#    205                                               ) -> Tile:
#    206                                                   """Extract a single tile and apply the transform pipeline.
#    207
#    208                                                   This is the worker function executed by each thread in :meth:`extract`.
#    209                                                   By fusing extraction and transforms in one call, I/O wait and CPU work
#    210                                                   overlap across tiles within the same batch.
#    211
#    212                                                   Parameters
#    213                                                   ----------
#    214                                                   slide : Slide
#    215                                                       The slide to read from.
#    216                                                   candidate : tuple[int, int, int, int, float]
#    217                                                       A single entry from :meth:`get_tile_candidates` in the form
#    218                                                       ``(x, y, w, h, tissue_ratio)`` in level-0 coordinates.
#    219
#    220                                                   Returns
#    221                                                   -------
#    222                                                   Tile
#    223                                                       Extracted and transformed tile.
#    224                                                   """
#    225       128     186069.0   1453.7      0.0          x, y, _, _, tissue_ratio = candidate
#    226       256     920791.0   3596.8      0.0          with self._profiler.phase("extract_tile"):
#    227       256 3561402272.0 1.39e+07     99.9              tile = slide.extract_tile(
#    228       128      50446.0    394.1      0.0                  coords=(x, y),
#    229       128      33448.0    261.3      0.0                  tile_size=self.tile_size,
#    230       128      53149.0    415.2      0.0                  magnification=self.magnification,
#    231                                                       )
#    232       128     324729.0   2536.9      0.0          tile.set_precomputed_tissue_ratio(tissue_ratio)
#    233       256    1245964.0   4867.0      0.0          with self._profiler.phase("apply_transforms"):
#    234       128     480431.0   3753.4      0.0              return self._apply_transforms(tile)
#
# Total time: 3.56 s
# File: /home/camilo/GlassCut/glasscut/slides/slide.py
# Function: Slide.extract_tile at line 176
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    176                                               def extract_tile(
#    177                                                   self,
#    178                                                   coords: tuple[int, int],
#    179                                                   tile_size: tuple[int, int],
#    180                                                   magnification: int | float,
#    181                                               ) -> Tile:
#    182                                                   """Extract a single tile from the slide at specified magnification.
#    183
#    184                                                   The requested magnification must be available on this slide.
#    185                                                   If the exact magnification is not available, a MagnificationError is raised.
#    186
#    187                                                   Parameters
#    188                                                   ----------
#    189                                                   coords : tuple[int, int]
#    190                                                       Coordinates (x, y) at level 0 (upper-left corner of the tile)
#    191                                                   tile_size : tuple[int, int]
#    192                                                       Desired tile size (width, height) in pixels
#    193                                                   magnification : int | float
#    194                                                       Target magnification (e.g., 40, 20, 10, 5)
#    195
#    196                                                   Returns
#    197                                                   -------
#    198                                                   Tile
#    199                                                       Extracted tile object
#    200
#    201                                                   Raises
#    202                                                   ------
#    203                                                   MagnificationError
#    204                                                       If the requested magnification is not available on this slide
#    205                                                   TileSizeOrCoordinatesError
#    206                                                       If the coordinates or tile size are invalid
#    207                                                   """
#    208                                                   # Get available magnifications
#    209       128     423829.0   3311.2      0.0          available_mags = self.magnifications
#    210
#    211                                                   # Validate magnification - this will raise MagnificationError if not available
#    212       128    1183459.0   9245.8      0.0          level = magnification_to_level(magnification, available_mags)
#    213
#    214                                                   # Validate coordinates in level-0 space using the true level footprint.
#    215       128     221776.0   1732.6      0.0          downsample = 2**level
#    216       128      83741.0    654.2      0.0          tile_size_lvl0 = (tile_size[0] * downsample, tile_size[1] * downsample)
#    217       128     902234.0   7048.7      0.0          if not self._has_valid_coords(coords, tile_size_lvl0):
#    218                                                       raise TileSizeOrCoordinatesError(
#    219                                                           f"Coordinates {coords} with tile_size {tile_size} at magnification "
#    220                                                           f"{magnification}x are invalid for slide dimensions {self.dimensions}. "
#    221                                                           f"Level-0 footprint is {tile_size_lvl0}."
#    222                                                       )
#    223
#    224       128      49800.0    389.1      0.0          if self._backend is None:
#    225                                                       raise RuntimeError("Slide not opened")
#    226
#    227                                                   # Read region from backend
#    228       256 3555564546.0 1.39e+07     99.9          image = self._backend.read_region(
#    229       128      32174.0    251.4      0.0              location=coords,
#    230       128      32109.0    250.9      0.0              level=level,
#    231       128      30349.0    237.1      0.0              size=tile_size,
#    232                                                   )
#    233
#    234       128    1478373.0  11549.8      0.0          return Tile(image, coords, magnification)

# %% [markdown]
# ## 5. Single extract_tile read-region timing
#
# Isolates the raw I/O cost.

# %%
import statistics

with Slide(str(slide_path), use_cucim=True) as slide5:
    candidates5 = GridTiler(
        tile_size=(512, 512), magnification=20, min_tissue_ratio=0.2, show_progress=False
    ).get_tile_candidates(slide5)
    sample_coords = [(x, y) for x, y, _, _, _ in candidates5[:50]]

    times_single: list[float] = []
    for coords in sample_coords:
        t = time.perf_counter()
        slide5.extract_tile(coords, (512, 512), 20)
        times_single.append(time.perf_counter() - t)

print(f"Single tile (n=50):")
print(f"  mean  = {statistics.mean(times_single)*1000:.1f} ms")
print(f"  median= {statistics.median(times_single)*1000:.1f} ms")
print(f"  stdev = {statistics.stdev(times_single)*1000:.1f} ms")
print(f"  min   = {min(times_single)*1000:.1f} ms")
print(f"  max   = {max(times_single)*1000:.1f} ms")
# Out:
# Single tile (n=50):
#   mean  = 26.6 ms
#   median= 25.8 ms
#   stdev = 7.1 ms
#   min   = 18.8 ms
#   max   = 39.8 ms

# %% [markdown]
# ## 6. Worker count sweep – find the parallelism sweet spot

# %%
from concurrent.futures import ThreadPoolExecutor

results: dict[int, float] = {}

tiler6 = GridTiler(
    tile_size=(512, 512), magnification=20, min_tissue_ratio=0.2, show_progress=False
)

with Slide(str(slide_path), use_cucim=True) as slide6:
    candidates6 = tiler6.get_tile_candidates(slide6)
    # Use only the first 256 candidates to keep the sweep fast
    sub = candidates6[:1]

    for n_w in [1, 2, 4, 8, 16, 32, 48, 64, 128, 256]:
        t = time.perf_counter()
        with ThreadPoolExecutor(max_workers=n_w) as executor:
            list(executor.map(lambda c: tiler6._extract_and_transform(slide6, c), sub))
        results[n_w] = time.perf_counter() - t

print("Workers | Time (s) | Tiles/s")
print("-" * 35)
for w, t in results.items():
    print(f"  {w:>4}  |  {t:5.3f}   |  {256/t:6.0f}")
# Out:
# Workers | Time (s) | Tiles/s
# -----------------------------------
#      1  |  0.035   |    7220
#      2  |  0.037   |    6961
#      4  |  0.027   |    9527
#      8  |  0.029   |    8762
#     16  |  0.020   |   12651
#     32  |  0.021   |   12351
#     48  |  0.026   |    9873
#     64  |  0.026   |    9734
#    128  |  0.037   |    6918
#    256  |  0.034   |    7547
